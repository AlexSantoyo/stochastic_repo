# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set_theme(style="whitegrid")

import random_variables as myrvs

# %%
n = 10
p = 0.5
binom1 = myrvs.BinomialRV(n,p)

print(binom1.expectation())
print(binom1.variance())
print(binom1.rv_name)
print(binom1)
# Out:
# 5.0
# 2.5
# Binomial
# A Binomial random variable instance.

# %%
binom_pmf = binom1.pmf()
binom_mgf = binom1.mgf()

# plt.bar(range(11),binom_pmf(range(11)))

# %%
sns.set_color_codes("dark")
sns.barplot(x = range(11), y = binom_pmf(range(11)))
plt.show()

# %%
t_ran = np.linspace(0,1,101)
sns.lineplot(x = t_ran, y = binom_mgf(t_ran))
# Out:
# <Axes: >
